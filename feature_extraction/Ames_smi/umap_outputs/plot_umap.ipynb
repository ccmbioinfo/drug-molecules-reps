# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
input_path = "/hpf/largeprojects/ccmbio/monikas/chem/feature_extraction/Ames_smi/umap_outputs/"

model1 = "msb-roshan/molgpt"
model4 = "DeepChem/ChemBERTa-77M-MTR"
model5 = "ncfrey/ChemGPT-1.2B"

# %% [markdown]
# ### Model 1: MolGPT

# %%
model = model1

def read_embeddings():
    name = model.split('/')[1]
    filename = input_path + "embeddings_" + name + ".csv"
    print(f"Filename: {filename}")
    df = pd.read_csv(filename)
    # print("Done")
    return df

def plot():
    embedding = read_embeddings()
    # values = embedding.values #TODO: read labels too for plotting another dataset
    # n_labels = len(values)
    # print(f"Number of labels: {n_labels}")
    # labels = np.repeat(np.arange(n_labels), 1) #hardcoding number of samples per label as 1, since we have only 1 row per molecule in csv
    # print(f"Embeddings:\n {values}")
    # print(f"{type(values)} {embedding.Dim1}")

    # umap.plot.points(values)
    
    # Plot the embedded data points
    _, ax = plt.subplots()
    scatter = ax.scatter(embedding.Dim1, embedding.Dim2, c=embedding.Labels.values, s=1, alpha=0.5)
    legend1 = ax.legend(*scatter.legend_elements(), title="Ames Test")
    ax.add_artist(legend1)
    ax.set_title('Ames_smi: MolGPT')
    ax.set_xlabel('Dimension 1')
    ax.set_ylabel('Dimension 2')
    plt.show()


plot()
# Out:
# Filename: /hpf/largeprojects/ccmbio/monikas/chem/feature_extraction/Ames_smi/umap_outputs/embeddings_molgpt.csv

# %% [markdown]
# ### Model 4: ChemBERT

# %%
model = model4

def read_csv():
    name = model.split('/')[1]
    filename = input_path + "embeddings_" + name + ".csv"
    print(f"Filename: {filename}")
    df = pd.read_csv(filename)
    return df

def plot():
    embedding = read_csv()
    # values = embedding.values #TODO: read labels too for plotting another dataset
    # n_labels = len(values)
    # print(f"Number of labels: {n_labels}")
    # labels = np.repeat(np.arange(n_labels), 1) #hardcoding number of samples per label as 1, since we have only 1 row per molecule in csv
    # print(f"Embeddings:\n {values}")
    # print(f"{type(values)} {embedding.Dim1}")

    # umap.plot.points(values)
    
    # Plot the embedded data points
    _, ax = plt.subplots()
    scatter = ax.scatter(embedding.Dim1, embedding.Dim2, c=embedding.Labels, s=1, alpha=0.5)
    legend1 = ax.legend(*scatter.legend_elements(), title="Ames Test")
    ax.add_artist(legend1)
    ax.set_title('Ames_smi: ChemBERT')
    ax.set_xlabel('Dimension 1')
    ax.set_ylabel('Dimension 2')
    plt.show()


plot()
# Out:
# Filename: /hpf/largeprojects/ccmbio/monikas/chem/feature_extraction/Ames_smi/umap_outputs/embeddings_ChemBERTa-77M-MTR.csv

# %% [markdown]
# ### Model 5: ChemGPT

# %%
model = model5

def read_csv():
    name = model.split('/')[1]
    filename = input_path + "embeddings_" + name + ".csv"
    print(f"Filename: {filename}")
    df = pd.read_csv(filename)
    return df

def plot():
    embedding = read_csv()
    # values = embedding.values #TODO: read labels too for plotting another dataset
    # n_labels = len(values)
    # print(f"Number of labels: {n_labels}")
    # labels = np.repeat(np.arange(n_labels), 1) #hardcoding number of samples per label as 1, since we have only 1 row per molecule in csv
    # print(f"Embeddings:\n {values}")
    # print(f"{type(values)} {embedding.Dim1}")

    # umap.plot.points(values)
    
    # Plot the embedded data points
    _, ax = plt.subplots()
    scatter = ax.scatter(embedding.Dim1, embedding.Dim2, c=embedding.Labels, label=embedding.Labels, s=1, alpha=0.5)
    legend1 = ax.legend(*scatter.legend_elements(), title="Ames Test")
    ax.add_artist(legend1)
    ax.set_title('Ames_smi: ChemGPT')
    ax.set_xlabel('Dimension 1')
    ax.set_ylabel('Dimension 2')
    plt.show()


plot()
# Out:
# Filename: /hpf/largeprojects/ccmbio/monikas/chem/feature_extraction/Ames_smi/umap_outputs/embeddings_ChemGPT-1.2B.csv
# Done
