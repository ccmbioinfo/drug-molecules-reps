# %%
import pandas as pd
# import umap
# import umap.plot
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
input_path = "/hpf/largeprojects/ccmbio/monikas/chem/feature_extraction/DUD_2d/DUD/umap_outputs/"

model1 = "msb-roshan/molgpt"
model4 = "DeepChem/ChemBERTa-77M-MTR"
model5 = "ncfrey/ChemGPT-1.2B"

target_list = {
               1: 'ace', 
               2: 'ache',
               3: 'ar',
               4: 'cdk2',
               5: 'cox2',
               6: 'dhfr',
               7: 'egfr',
               8: 'er_agonist',
               9: 'fgfr1',
               10: 'fxa',
               11: 'gpb',
               12: 'gr',
               13: 'hivrt',
               14: 'inha',
               15: 'na',
               16: 'p38',
               17: 'parp',
               18: 'pdgfrb',
               19: 'sahh',
               20: 'src',
               21:'vegfr2'
               }

# %% [markdown]
# ### Model 1: MolGPT

# %%
model = model1
model_name = model.split('/')[1]

def read_csv(target):
    filename = input_path + "embeddings_" + target + "_" + model_name + ".csv"
    # print(f"Filename: {filename}")
    df = pd.read_csv(filename)
    return df

def plot():
    
    # Plot the embedded data points
    num_targets = len(target_list)
    ncols = 3
    nrows = (num_targets + ncols - 1) // ncols  # Calculate number of rows needed

    # Create a figure with the specified number of subplots
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, nrows*4))
    axes = axes.flatten()
    red_patch = mpatches.Patch(color='red', label='Actives')
    green_patch = mpatches.Patch(color='green', label='Decoys')
    for axis, target in zip(axes, target_list.values()):
        embedding = read_csv(target)
        print(f"EMbedding: {embedding}")
        colors = ['red' if label == 'actives' else 'green' for label in embedding.Labels]
        axis.scatter(embedding.Dim1, embedding.Dim2, c=colors, s=5, alpha=0.5)
        legend1 = axis.legend(handles = [red_patch, green_patch] , title="Target molecules")
        axis.add_artist(legend1)
        axis.set_title(target + ': MolGPT')
        axis.set_xlabel('Dimension 1')
        axis.set_ylabel('Dimension 2')
     
    
     # Hide any unused subplots
    for i in range(num_targets, len(axes)):
        fig.delaxes(axes[i])
    
    plt.tight_layout()
    plt.show()

plot()
# Out:
# EMbedding:       Unnamed: 0       Dim1       Dim2   Labels
# 0              0   9.571016  12.373993  actives
# 1              1   7.485059  12.022202  actives
# 2              2   6.799488  20.388480  actives
# 3              3   7.081738  11.016761  actives
# 4              4   7.094600  11.018203  actives
# ...          ...        ...        ...      ...
# 1837        1837   6.681549  20.369476   decoys
# 1838        1838   9.362420   1.384600   decoys
# 1839        1839   1.705573  -1.144808   decoys
# 1840        1840  11.640013   4.869274   decoys
# 1841        1841  12.000726   9.957616   decoys
#
# [1842 rows x 4 columns]
# EMbedding:       Unnamed: 0       Dim1      Dim2   Labels
# 0              0  15.834861  0.716007  actives
# 1              1  15.681212  0.618018  actives
# 2              2  15.586146  0.565686  actives
# 3              3  15.430519  0.440627  actives
# 4              4  15.606616  0.576065  actives
# ...          ...        ...       ...      ...
# 3953        3953  10.755587  2.903294   decoys
# 3954        3954   8.429133  0.744113   decoys
# 3955        3955   7.853160  5.103075   decoys
# 3956        3956   3.953123  5.594711   decoys
# 3957        3957  14.456465  3.619931   decoys
#
# [3958 rows x 4 columns]
# EMbedding:       Unnamed: 0       Dim1       Dim2   Labels
# 0              0  13.020382   3.390621  actives
# 1              1   7.061805   2.990131  actives
# 2              2   5.668623   5.806370  actives
# 3              3   5.677933   5.762565  actives
# 4              4   6.661409   2.543821  actives
# ...          ...        ...        ...      ...
# 2911        2911  12.192639  10.634754   decoys
# 2912        2912  12.181689  10.535020   decoys
# 2913        2913  12.169084  10.525125   decoys
# 2914        2914   6.786020   4.460020   decoys
# 2915        2915   6.793546   4.413381   decoys
#
# [2916 rows x 4 columns]
# EMbedding:       Unnamed: 0       Dim1      Dim2   Labels
# 0              0   3.333021  3.208239  actives
# 1              1   5.834369  4.286245  actives
# 2              2   5.780454  4.288837  actives
# 3              3   5.825212  4.262659  actives
# 4              4   5.794198  4.288483  actives
# ...          ...        ...       ...      ...
# 2112        2112  12.411656  9.969273   decoys
# 2113        2113   5.804684  5.801684   decoys
# 2114        2114   7.008938  1.405144   decoys
# 2115        2115   7.058954  1.951772   decoys
# 2116        2116   7.217434  6.202700   decoys
#
# [2117 rows x 4 columns]
# EMbedding:        Unnamed: 0      Dim1      Dim2   Labels
# 0               0 -6.558312 -2.031881  actives
# 1               1 -5.806993 -2.198701  actives
# 2               2  5.282690  1.401463  actives
# 3               3 -1.994103 -4.429564  actives
# 4               4  4.255162 -1.250200  actives
# ...           ...       ...       ...      ...
# 12813       12813 -4.384931  3.376587   decoys
# 12814       12814  3.177998  9.283694   decoys
# 12815       12815  3.223214  9.248115   decoys
# 12816       12816  8.128036  8.225036   decoys
# 12817       12817  4.718297 -4.411500   decoys
#
# [12818 rows x 4 columns]

# %% [markdown]
# ### Model 4: ChemBERT

# %%
model = model4
model_name = model.split('/')[1]

def read_csv(target):
    filename = input_path + "embeddings_" + target + "_" + model_name + ".csv"
    # print(f"Filename: {filename}")
    df = pd.read_csv(filename)
    return df

def plot():
    
    # Plot the embedded data points
    num_targets = len(target_list)
    ncols = 3
    nrows = (num_targets + ncols - 1) // ncols  # Calculate number of rows needed

    # Create a figure with the specified number of subplots
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, nrows*4))
    axes = axes.flatten()
    red_patch = mpatches.Patch(color='red', label='Actives')
    green_patch = mpatches.Patch(color='green', label='Decoys')
    for axis, target in zip(axes, target_list.values()):
        embedding = read_csv(target)
        print(f"EMbedding: {embedding}")
        colors = ['red' if label == 'actives' else 'green' for label in embedding.Labels]
        axis.scatter(embedding.Dim1, embedding.Dim2, c=colors, s=5, alpha=0.5)
        legend1 = axis.legend(handles = [red_patch, green_patch] , title="Target molecules")
        axis.add_artist(legend1)
        axis.set_title(target + ': MolGPT')
        axis.set_xlabel('Dimension 1')
        axis.set_ylabel('Dimension 2')
     
    
     # Hide any unused subplots
    for i in range(num_targets, len(axes)):
        fig.delaxes(axes[i])
    
    plt.tight_layout()
    plt.show()

plot()

# %% [markdown]
# ### Model 5: ChemGPT

# %%
model = model5

model_name = model.split('/')[1]

def read_csv(target):
    filename = input_path + "embeddings_" + target + "_" + model_name + ".csv"
    # print(f"Filename: {filename}")
    df = pd.read_csv(filename)
    return df

def plot():
    
    # Plot the embedded data points
    num_targets = len(target_list)
    ncols = 3
    nrows = (num_targets + ncols - 1) // ncols  # Calculate number of rows needed

    # Create a figure with the specified number of subplots
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, nrows*4))
    axes = axes.flatten()
    red_patch = mpatches.Patch(color='red', label='Actives')
    green_patch = mpatches.Patch(color='green', label='Decoys')
    for axis, target in zip(axes, target_list.values()):
        embedding = read_csv(target)
        print(f"EMbedding: {embedding}")
        colors = ['red' if label == 'actives' else 'green' for label in embedding.Labels]
        axis.scatter(embedding.Dim1, embedding.Dim2, c=colors, s=5, alpha=0.5)
        legend1 = axis.legend(handles = [red_patch, green_patch] , title="Target molecules")
        axis.add_artist(legend1)
        axis.set_title(target + ': MolGPT')
        axis.set_xlabel('Dimension 1')
        axis.set_ylabel('Dimension 2')
     
    
     # Hide any unused subplots
    for i in range(num_targets, len(axes)):
        fig.delaxes(axes[i])
    
    plt.tight_layout()
    plt.show()

plot()
